# %% [markdown]
# # 1. Setting Environment

# %%
import pandas as pd

# %%
from os import chdir, getcwd

# %%
wd=getcwd()
chdir('C:\\Users\\')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Loading Data

# %% [markdown]
# ### 2.1 data

# %%
data = pd.read_csv('제5회 Big Data Competition-분석용데이터-01.Pruduct.csv',engine='python',encoding='utf-8')

# %%
data.reset_index(level=None,inplace=True)

# %%
data.columns= ['CLNT_ID','SESS_ID','HITS_SEQ','PD_C','PD_ADD_NM','PD_BRA_NM','PD_BUY_AM','PD_BUY_CT']

# %%
data
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 0        4139680   7605037        12  642112
# 1        4140076  10189797        13  570603
# 2        4142395   6158159        85  179538
# 3        4144914   7935714        12  554336
# 4        4144917   6406509        78  190306
# 5        4147643   4050743        66  149995
# 6        4147739   6881895        10  568751
# 7        4148106   6537318        21  570603
# 8        4148129   3942102         2  755148
# 9        4148527   5718021        19  608620
# 10       4150259   4098361        90  537513
# 11       4153618    729571        42   77900
# 12       4154576   4253415        19  591229
# 13       4157355   6349580        34  554700
# 14       4159738   3278944        42  184776
# 15       4160219   9232020        32  368706
# 16       4161209   3612192       247  125473
# 17       4167192  10832157       189  479110
# 18       4169076   4316808        24  296741
# 19       4170352   4651820       387  166295
# ...

# %%
data.pivot()

# %% [markdown]
# ---

# %% [markdown]
# ### 2.2 data2

# %%
data2 = pd.read_csv('제5회 Big Data Competition-분석용데이터-02.Search1.csv',engine='python',encoding='utf-8')

# %%
data2.reset_index(level=None,inplace=True)

# %%
data2.columns = ['CLNT_ID','SESS_ID','KWD_NM','SEARCH_CNT']

# %%
data2
# Out:
#          CLNT_ID   SESS_ID      KWD_NM  SEARCH_CNT
# 0        5607714   7112876    빌리프 아이크림           6
# 1        5607714   4090791   프리메라 마스크팩           3
# 2        5607714   4090791       여성청결제           1
# 3        5612428   1876482        명품가방           1
# 4        5612428    658123   콩순이 아이스크림           1
# 5        5612428   1876482  블루독 티셔츠 남아           1
# 6        5612471   8539312       쉬폰원피스           1
# 7        5612471   8539312  여성 쉬폰 블라우스           1
# 8        5613055   8510027      임산부 팬티           2
# 9        5613055   8510027     임산부 원피스           1
# 10       5609603  10483281       베베드피노          27
# 11       5609603  10483281         쁘띠뮤           6
# 12       5609603  10483281   베베드피노 티셔츠           2
# 13       5609763   6286724   남성 반팔 티셔츠           4
# 14       5609800   7380789    메트로시티 지갑           1
# 15       5609800  10249029   닥스 양말선물세트           1
# 16       5609800   7380789       크로커다일           2
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2.3 data3

# %%
data3 = pd.read_csv('제5회 Big Data Competition-분석용데이터-03.Search2.csv',engine='python',encoding='utf-8')

# %%
data3.reset_index(level=0,inplace=True,col_level=0) #2번 하기

# %%
data3.columns = ['KWD_NM','SESS_DT','SEARCH_CNT']

# %%
data3
# Out:
#                   KWD_NM   SESS_DT SEARCH_CNT
# 0                  닥스원피스  20180407          8
# 1              닥터지 브라이트닝  20180407          1
# 2                 달팡 인트랄  20180407          2
# 3                    대상트  20180407          1
# 4                   더블유닷  20180407          6
# 5              더블하트 모유실감  20180407          1
# 6               데님 롱 스커트  20180407          6
# 7                 데상트 크론  20180407         12
# 8                데상트골프여성  20180407          6
# 9                데상트여성골프  20180407          1
# 10              데상트여성티셔츠  20180407          2
# 11                 데코뷰커튼  20180407          4
# 12                   덴탈껌  20180407          1
# 13                도깨비방망이  20180407          8
# 14                  도마꽂이  20180407          6
# 15                  동물잠옷  20180407         31
# 16               동서가구 쇼파  20180407          1
# 17                   돼지코  20180407          1
# 18                    드넬  20180407          4
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2.4 data4

# %%
data4 = pd.read_csv('제5회 Big Data Competition-분석용데이터-04.Custom.csv',engine='python',encoding='utf-8')

# %%
data4.reset_index(level=0,inplace=True,col_level=0) #2번하기

# %%
data4.columns = ['CLNT_GENDER','CLNT_ID','CLNT_AGE']

# %%
data4
# Out:
#        CLNT_GENDER  CLNT_ID  CLNT_AGE
# 0                F  4830726        30
# 1                F  4830874        40
# 2                F  4830975        30
# 3                F  4831275        30
# 4                F  4825325        30
# 5                F  4825382        40
# 6                F  4825797        40
# 7                F  4825908        30
# 8                F  4825961        30
# 9                M  4840532        40
# 10               F  4840825        10
# 11               F  4843304        30
# 12               F  4843591        30
# 13               F  4843997        30
# 14               F  4846369        30
# 15               F  4846380        20
# 16               M  4846440        40
# 17               M  4846511        40
# 18               F  4846738        20
# 19               F  4846869        30
# 20               F  4847147        20
# 21               F  4839353        30
# 22               F  4839427        30
# 23               F  4839489        40
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2.5 data5

# %%
data5 = pd.read_csv('제5회 Big Data Competition-분석용데이터-05.Session.csv',engine='python',encoding='utf-8')

# %%
data5.info() #2712907
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2712907 entries, (5873599, 8641867, 9, 20180509, 82.0, 1,890, mobile, Daejeon) to (3573758, 8702345, 17, 20180508, 18.0, 373, desktop, Chungcheongbuk-do)
# Data columns (total 1 columns):
# CLNT_ID    object
# dtypes: object(1)
# memory usage: 92.9+ MB

# %%
data5.reset_index(level=None,inplace=True)

# %%
data5
# Out:
#          level_0   level_1  level_2   level_3  level_4 level_5  level_6  \
# 0        5873599   8641867        9  20180509     82.0   1,890   mobile
# 1        5873599   6616320       21  20180611    105.0   1,604   mobile
# 2        5873599   5886172       40  20180624     41.0     632   mobile
# 3        5873884   1050889       15  20180913    160.0   1,035   mobile
# 4        5874461  10298270        5  20180412     13.0     298   mobile
# 5        5874701    608577       65  20180920     41.0     444   mobile
# 6        5874829   1666766       87  20180903     36.0     340   mobile
# 7        5874829   1670494       86  20180903    103.0     976   mobile
# 8        5874829   1694242       85  20180902    154.0   3,099   mobile
# 9        5874829   1559438       92  20180904     24.0     317   mobile
# 10       5874900  10229983        7  20180413    207.0   4,143   mobile
# 11       5874907     10855        2  20180930      4.0     263  desktop
# ...

# %%
data5.columns=['CLNT_ID','SESS_ID','SESS_SEQ','SESS_DT','TOT_PAG_VIEW_CT','TOT_SESS_HR_V','DVC_CTG_NM','ZON_NM','CITY_NM']

# %%
data5
# Out:
#          CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0        5873599   8641867         9  20180509             82.0         1,890
# 1        5873599   6616320        21  20180611            105.0         1,604
# 2        5873599   5886172        40  20180624             41.0           632
# 3        5873884   1050889        15  20180913            160.0         1,035
# 4        5874461  10298270         5  20180412             13.0           298
# 5        5874701    608577        65  20180920             41.0           444
# 6        5874829   1666766        87  20180903             36.0           340
# 7        5874829   1670494        86  20180903            103.0           976
# 8        5874829   1694242        85  20180902            154.0         3,099
# 9        5874829   1559438        92  20180904             24.0           317
# 10       5874900  10229983         7  20180413            207.0         4,143
# ...

# %% [markdown]
# ### 2.6 data6

# %%
data6 = pd.read_csv('제5회 Big Data Competition-분석용데이터-06.Master.csv',delimiter="\r\t",engine='python',encoding='utf-8')

# %%
data6.columns=['col_name']

# %%
data6
# Out:
#                                                  col_name
# 0       "064382",언더아머 남성 UA HG 아머 모크 LS 1289559-001 - ...
# 1       "062282",여자 플라워덧신 2족선물세트 17403-2set,속옷/양말/홈웨어,...
# 2       "061729","88A2933253배트맨스웨트티 - 블랙 / 130",유아동의류,...
# 3       "061537","닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm...
# 4       "058820",여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) ...
# 5       "058280",선염스트라이프레이스패치원피스 JROP521D - 블루 / 85,여성...
# 6       "058183",[17S/S]  울 자카드 져지 자켓 9317111001056 - ...
# 7       "058098",V넥 고방 체크 롱 원피스 (K65-54615) - 스카이블루(SB...
# 8       "058057",배색포인트 랩스타일 원피스 (GIHOP921F) - 화이트 / F,...
# 9       "056306",선염 체크나염 여성잠옷(VPT3570WP) - 핑크 / 95,속옷/...
# 10      "055076",정장형스판바지C72P158 - 베이지(BE) / 55(90),여성의...
# 11      "318122","H1280YRJ,K,N토트백&크로스백 - 그레이",패션잡화,여성가...
# 12      "318011",가볍고 편안한 남성 워킹화 페이스투스 1117SW310 - 블랙 /...
# 13      "317956",체크패턴 프릴포인트 스커트GHB6SK740F - 078(민트) / ...
# 14      "127096",(KM)굿찌쿨통팬츠/빅사이즈/통바지/와이드팬츠 - 베이지 / 2번,...
# ...

# %%
data6_1 = data6.col_name.str.split(",",expand=True,n=1)

# %%
data6_1.columns = ['PD_C','REST']

# %%
data6_1
# Out:
#             PD_C                                               REST
# 0       "064382"  언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[9...
# 1       "062282"  여자 플라워덧신 2족선물세트 17403-2set,속옷/양말/홈웨어,여성양말류,여성일반양말
# 2       "061729"  "88A2933253배트맨스웨트티 - 블랙 / 130",유아동의류,유아의류상의,영유...
# 3       "061537"  "닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)",패션잡화...
# 4       "058820"  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...
# 5       "058280"  선염스트라이프레이스패치원피스 JROP521D - 블루 / 85,여성의류,여성의류전신...
# 6       "058183"  [17S/S]  울 자카드 져지 자켓 9317111001056 - 네이비 / 100...
# 7       "058098"  V넥 고방 체크 롱 원피스 (K65-54615) - 스카이블루(SB) / F,여성의...
# 8       "058057"  배색포인트 랩스타일 원피스 (GIHOP921F) - 화이트 / F,여성의류,여성의류...
# 9       "056306"  선염 체크나염 여성잠옷(VPT3570WP) - 핑크 / 95,속옷/양말/홈웨어,홈웨...
# 10      "055076"  정장형스판바지C72P158 - 베이지(BE) / 55(90),여성의류,여성의류하의,...
# 11      "318122"       "H1280YRJ,K,N토트백&크로스백 - 그레이",패션잡화,여성가방,여성토트백
# 12      "318011"  가볍고 편안한 남성 워킹화 페이스투스 1117SW310 - 블랙 / 255,스포츠패...
# ...

# %%
data6_1.REST.str.split(",",expand=True,n=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5024906 entries, 0 to 5024905
# Data columns (total 8 columns):
# CLNT_ID      int64
# SESS_ID      int64
# HITS_SEQ     int64
# PD_C         int64
# PD_ADD_NM    object
# PD_BRA_NM    object
# PD_BUY_AM    object
# PD_BUY_CT    object
# dtypes: int64(4), object(4)
# memory usage: 306.7+ MB

# %%
data
# Out:
#                                                                                     CLNT_ID
# 4139680 7605037  12  642112 색상:워터멜론                             [바비브라운]      39,000       1
# 4140076 10189797 13  570603 색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개    데상트          39,000       2
# 4142395 6158159  85  179538 (not set)                           [아베다]        39,000       1
# 4144914 7935714  12  554336 색상:블랙|사이즈:160cm(12~13세) / 1개        아디다스 키즈      39,000       1
# 4144917 6406509  78  190306 5개                                  데코르테         39,000       5
# 4147643 4050743  66  149995 사이즈:옵션04.AN868_04 / 1개              앵글로매니아       39,000       1
# 4147739 6881895  10  568751 신발색상:블랙(BK)/신발사이즈:280               [디스커버리]      39,000       1
# 4148106 6537318  21  570603 색상:BLK0_(BLK0)BLACK|사이즈:115 / 1개    데상트          39,000       1
# 4148129 3942102  2   755148 모델명:올나이터 / 1개                       어반디케이        39,000       1
# ...

# %%
data
